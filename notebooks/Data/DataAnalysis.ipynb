# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv("gain.csv")
df["g"] = df["g"].str.replace(" + 0.i", "").astype(float)

df.head()
# Out:
#      mu    g
# 0 -10.0  1.0
# 1  -9.9  1.0
# 2  -9.8  1.0
# 3  -9.7  1.0
# 4  -9.6  1.0

# %%
plt.plot(df["mu"], df["g"])
